# %%
# !pip install torch transformers pandas
# Out:
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: transformers in /opt/anaconda3/lib/python3.12/site-packages (4.49.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (0.29.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/lib/python3.12/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import pandas as pd
import re
import time
import random

# --- Step 1: Load the Model and Tokenizer ---
model_name = "EleutherAI/gpt-neo-125M"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using M1 GPU (MPS) for acceleration.")
else:
    device = torch.device("cpu")
    print("MPS not available, falling back to CPU.")
model.to(device)

# --- Step 2: Define a Simple Prompt ---
domain_prompt = """
Name: [First Last]
Rating: [1-5]
Comment: [10-20 word review]
"""

# --- Step 3: Function to Generate Synthetic Data ---
def generate_synthetic_review(attempt=0, max_attempts=3):
    """
    Generate a single synthetic customer review using GPT-Neo.
    
    Args:
        attempt (int): Current retry attempt.
        max_attempts (int): Max retries to avoid infinite loops.
    
    Returns:
        dict: Parsed review with 'Name', 'Rating', and 'Comment'.
    """
    if attempt >= max_attempts:
        print(f"Max attempts reached. Using fallback with variation.")
        return {
            "Name": f"User{random.randint(1, 100)} Smith",
            "Rating": random.randint(1, 5),
            "Comment": "Generic review with some variation here."
        }
    
    print("Starting generation...")
    start_time = time.time()
    
    # Add a random seed to prompt
    seed = random.randint(0, 10000)
    prompt = domain_prompt + f"\nSeed: {seed}\n"
    
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    print("Inputs prepared.")
    
    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_length=150,    # Increased to ensure full review
            num_beams=4,      # More beams for structure
            temperature=1.2,  # Higher for creativity
            top_k=50,
            top_p=0.9,       # Add top-p sampling
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )
    print(f"Generation completed in {time.time() - start_time:.2f} seconds.")
    
    generated_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)
    print(f"Generated text:\n{generated_text}\n")
    
    # Parse the generated text
    try:
        lines = [line.strip() for line in generated_text.split("\n") if line.strip()]
        print(f"Lines after filtering:\n{lines}\n")
        
        # Look for Name, Rating, Comment anywhere in the text
        name = None
        rating = None
        comment = None
        for line in lines:
            if re.match(r"Name: .+", line):
                name = re.search(r"Name: (.+)", line).group(1).strip()
            elif re.match(r"Rating: \d", line):
                rating = int(re.search(r"Rating: (\d)", line).group(1))
            elif re.match(r"Comment: .+", line):
                comment = re.search(r"Comment: (.+)", line).group(1).strip()
        
        if not all([name, rating, comment]):
            print("Incomplete review, retrying...")
            return generate_synthetic_review(attempt + 1, max_attempts)
        
        if rating < 1 or rating > 5:
            rating = max(1, min(5, rating))  # Clamp rating
        print(f"Parsed review: Name={name}, Rating={rating}, Comment={comment}")
        return {"Name": name, "Rating": rating, "Comment": comment}
    except (AttributeError, IndexError, ValueError) as e:
        print(f"Error parsing review: {e}. Retrying...")
        return generate_synthetic_review(attempt + 1, max_attempts)

# --- Step 4: Generate and Save Dataset ---
def create_synthetic_dataset(num_rows=10):
    """
    Generate a dataset of synthetic reviews and save to CSV.
    
    Args:
        num_rows (int): Number of rows to generate (default 10).
    """
    reviews = []
    for i in range(num_rows):
        print(f"\nGenerating review {i+1}/{num_rows}")
        review = generate_synthetic_review()
        reviews.append(review)
    
    df = pd.DataFrame(reviews, columns=["Name", "Rating", "Comment"])
    df.to_csv("synthetic_customer_reviews.csv", index=False)
    print(f"\nGenerated {len(df)} synthetic reviews. Saved to 'synthetic_customer_reviews.csv'.")
    
    print("\nDataset Statistics:")
    print(f"Mean Rating: {df['Rating'].mean():.2f}")
    print(f"Rating Variance: {df['Rating'].var():.2f}")
    print(f"Sample Review:\n{df.iloc[0]}")

# --- Step 5: Run the Generator ---
if __name__ == "__main__":
    print("Starting Synthetic Data Generation...")
    create_synthetic_dataset(num_rows=10)
# Out:
# Using M1 GPU (MPS) for acceleration.
# Starting Synthetic Data Generation...
#
# Generating review 1/10
# Starting generation...
# Inputs prepared.
# Generation completed in 24.76 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7009
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7009', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 9.52 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7077
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7077
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7077
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7077
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7077
# Rating: [1-5]
# Comment: [10
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7077', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7077', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7077', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7077', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7077', 'Rating: [1-5]', 'Comment: [10']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 8.54 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 5946
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 5946', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Max attempts reached. Using fallback with variation.
#
# Generating review 2/10
# Starting generation...
# Inputs prepared.
# Generation completed in 7.82 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7979
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7976
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7976
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7976
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7976
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7979', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7976', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7976', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7976', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7976', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 10.83 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3021
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3021
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3021
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3021
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3021
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3021', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3021', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3021', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3021', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3021', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 10.04 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3932
# Description: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3932
# Description: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3932
# Description: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3932
# Description: [First Last]
# Rating: [1-5]
# Comment: [10-20
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3932', 'Description: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3932', 'Description: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3932', 'Description: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3932', 'Description: [First Last]', 'Rating: [1-5]', 'Comment: [10-20']
#
# Incomplete review, retrying...
# Max attempts reached. Using fallback with variation.
#
# Generating review 3/10
# Starting generation...
# Inputs prepared.
# Generation completed in 8.01 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4055
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4055', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 8.51 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4061
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4062
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4063
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4064
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4065
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4061', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4062', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4063', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4064', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4065', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 7.80 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9897
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9897
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9897
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9897
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9897
#
# Rating: [1-5]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9897', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9897', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9897', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9897', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9897', 'Rating: [1-5]']
#
# Incomplete review, retrying...
# Max attempts reached. Using fallback with variation.
#
# Generating review 4/10
# Starting generation...
# Inputs prepared.
# Generation completed in 8.10 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9035
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9035
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9035
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9035
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9035
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9035', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9035', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9035', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9035', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9035', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 11.17 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 1944
#
# Rating: [1-5]
# Comment: [20-30 word review]
#
# Seed: 1944
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 1944
#
# Rating: [1-5]
# Comment: [20-30 word review]
#
# Seed: 1944
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 1944
#
# Rating: [1-5]
# Comment: [20-30 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 1944', 'Rating: [1-5]', 'Comment: [20-30 word review]', 'Seed: 1944', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 1944', 'Rating: [1-5]', 'Comment: [20-30 word review]', 'Seed: 1944', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 1944', 'Rating: [1-5]', 'Comment: [20-30 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 8.33 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 95
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 95
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 95
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 95
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 95
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed:
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 95', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 95', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 95', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 95', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 95', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed:']
#
# Incomplete review, retrying...
# Max attempts reached. Using fallback with variation.
#
# Generating review 5/10
# Starting generation...
# Inputs prepared.
# Generation completed in 9.01 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 9412
#
# Seed: 94
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 9412', 'Seed: 94']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 7.75 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7749
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7814
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7816
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7817
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 7818
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7749', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7814', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7816', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7817', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 7818', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 12.70 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8517
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8517', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Name: [First Last]', 'Rating: [1-5]', 'Comment: [10']
#
# Incomplete review, retrying...
# Max attempts reached. Using fallback with variation.
#
# Generating review 6/10
# Starting generation...
# Inputs prepared.
# Generation completed in 10.19 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6127
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6127', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 7.97 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6544
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6544
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6544
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6544
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6544
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6544', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6544', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6544', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6544', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6544', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 8.08 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9594
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9594
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9594
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9594
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 9594
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9594', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9594', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9594', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9594', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 9594', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Max attempts reached. Using fallback with variation.
#
# Generating review 7/10
# Starting generation...
# Inputs prepared.
# Generation completed in 8.22 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6795
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6795
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6795
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6795
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6795
#
# Rating: [1-5]
# Comment: [10
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6795', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6795', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6795', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6795', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6795', 'Rating: [1-5]', 'Comment: [10']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 7.91 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 182
# Rating: [1-5]
# Comment: [10-20 word review]
#
# A:
#
# You can use the following code to get the first and last names:
#
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 182', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'A:', 'You can use the following code to get the first and last names:']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 8.12 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8300
# Rating: [0-10]
# Comment: [10-20 word review]
#
# Seed: 8300
# Rating: [0-10]
# Comment: [10-20 word review]
#
# Seed: 8300
# Rating: [0-10]
# Comment: [10-20 word review]
#
# Seed: 8300
# Rating: [0-10]
# Comment: [10-20 word review]
#
# Seed: 8300
# Rating: [0-10]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8300', 'Rating: [0-10]', 'Comment: [10-20 word review]', 'Seed: 8300', 'Rating: [0-10]', 'Comment: [10-20 word review]', 'Seed: 8300', 'Rating: [0-10]', 'Comment: [10-20 word review]', 'Seed: 8300', 'Rating: [0-10]', 'Comment: [10-20 word review]', 'Seed: 8300', 'Rating: [0-10]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Max attempts reached. Using fallback with variation.
#
# Generating review 8/10
# Starting generation...
# Inputs prepared.
# Generation completed in 9.14 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6020
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6020
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6020
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6020
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6020
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6020', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6020', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6020', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6020', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6020', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 9.61 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 5529
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 5528
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 5529
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 5528
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 5529
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 5529', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 5528', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 5529', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 5528', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 5529', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 9.12 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 2045
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 2046
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 2047
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 2048
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 2049
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 2045', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 2046', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 2047', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 2048', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 2049', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Max attempts reached. Using fallback with variation.
#
# Generating review 9/10
# Starting generation...
# Inputs prepared.
# Generation completed in 8.21 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8559
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8559
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8559
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8559
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8559
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8559', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8559', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8559', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8559', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8559', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 9.41 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6929
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6931
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6932
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6933
#
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 6934
#
# Rating: [1-5]
# Comment: [10
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6929', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6931', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6932', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6933', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 6934', 'Rating: [1-5]', 'Comment: [10']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 7.72 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4140
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4140
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4140
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4140
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 4140
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4140', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4140', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4140', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4140', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 4140', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Max attempts reached. Using fallback with variation.
#
# Generating review 10/10
# Starting generation...
# Inputs prepared.
# Generation completed in 7.87 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8257
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8257
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8257
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8257
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8257
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8257', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8257', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8257', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8257', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8257', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 7.74 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3613
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3613
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3613
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3613
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 3613
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3613', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3613', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3613', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3613', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 3613', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Starting generation...
# Inputs prepared.
# Generation completed in 8.06 seconds.
# Generated text:
#
# Name: [First Last]
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8174
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8174
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8174
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8174
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Seed: 8174
# Rating: [1-5]
# Comment: [10-20 word review]
#
# Lines after filtering:
# ['Name: [First Last]', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8174', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8174', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8174', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8174', 'Rating: [1-5]', 'Comment: [10-20 word review]', 'Seed: 8174', 'Rating: [1-5]', 'Comment: [10-20 word review]']
#
# Incomplete review, retrying...
# Max attempts reached. Using fallback with variation.
#
# Generated 10 synthetic reviews. Saved to 'synthetic_customer_reviews.csv'.
#
# Dataset Statistics:
# Mean Rating: 2.80
# Rating Variance: 1.73
# Sample Review:
# Name                                   User47 Smith
# Rating                                            2
# Comment    Generic review with some variation here.
# Name: 0, dtype: object
